# %%
import pandas as pd
import numpy as np

# %%
weather_total = pd.read_csv('final_weather_table.txt',low_memory=False)
weather_total.head()
# Out:
#    Unnamed: 0    YYMM State   WBAN  Latitude  Longitude AvgTemp  \
# 0           0  199607    AK  25704    51.883   -176.650    51.6
# 1           1  199607    AL  13894    30.688    -88.246    81.7
# 2           2  199607    AL  13895    32.301    -86.394    80.8
# 3           3  199607    AL   3856    34.644    -86.786    78.2
# 4           4  199607    AR  13964    35.334    -94.365    79.7
#
#   TotalMonthlyPrecip Avgwindspeed
# 0               0.22          NaN
# 1               4.95          5.6
# 2               8.72          4.8
# 3                4.7          5.6
# 4               7.67          5.3

# %%
windspeed = weather_total.iloc[:,[1,2,3,-1]]
precip = weather_total.iloc[:,[1,2,3,-2]]
temp = weather_total.iloc[:,[1,2,3,-3]]

# %%
statelist = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 
             'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 
             'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 
             'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
#WindSpeed
windspeed.replace('M',np.nan,inplace=True)
windspeed.dropna(inplace=True)
windspeed.head(10)
# Out:
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#       YYMM State   WBAN Avgwindspeed
# 1   199607    AL  13894          5.6
# 2   199607    AL  13895          4.8
# 3   199607    AL   3856          5.6
# 4   199607    AR  13964          5.3
# 5   199607    AZ  93167         10.7
# 6   199607    AZ   3103          5.2
# 7   199607    AZ   3145          9.8
# 9   199607    AZ  23194          8.1
# 10  199607    AZ  23160          7.6
# 11  199607    AZ  23183          6.7

# %%
#extract one state and reset index
AZ = windspeed[windspeed['State'].isin(['AZ'])]
AZ.reset_index(inplace=True)
AZ = AZ.iloc[:,1:]
AZ.head()
AZ
# Out:
#         YYMM State   WBAN Avgwindspeed
# 0     199607    AZ  93167         10.7
# 1     199607    AZ   3103          5.2
# 2     199607    AZ   3145          9.8
# 3     199607    AZ  23194          8.1
# 4     199607    AZ  23160          7.6
# 5     199607    AZ  23183          6.7
# 6     199608    AZ  23194          8.1
# 7     199608    AZ  93167         10.4
# 8     199608    AZ  23183          6.8
# 9     199608    AZ   3195          5.4
# 10    199608    AZ   3145          9.4
# 11    199608    AZ   3103          5.3
# 12    199608    AZ  23160          8.1
# 13    199609    AZ  93167          9.6
# 14    199609    AZ  23194          7.4
# 15    199609    AZ  23160          6.3
# 16    199609    AZ  23183          5.9
# 17    199609    AZ   3195          5.8
# 18    199609    AZ   3103          5.3
# 19    199609    AZ   3145          8.0
# 20    199610    AZ  93167         10.1
# 21    199610    AZ  23194          7.9
# 22    199610    AZ  23160          7.4
# 23    199610    AZ  23183          5.4
# 24    199610    AZ   3195          6.7
# 25    199610    AZ   3103          6.3
# 26    199611    AZ  23183          4.5
# 27    199611    AZ  23194          6.7
# 28    199611    AZ  93167          8.9
# 29    199611    AZ   3195          6.3
# ...      ...   ...    ...          ...
# 3480  201611    AZ  23184          5.7
# 3481  201611    AZ   3103          6.7
# 3482  201611    AZ  93167          7.8
# 3483  201611    AZ  53146         10.3
# 3484  201611    AZ   3029          5.0
# 3485  201611    AZ  23194          5.9
# 3486  201611    AZ   3145          6.6
# 3487  201611    AZ   3195          6.4
# 3488  201611    AZ  93027          6.9
# 3489  201611    AZ   3192          3.8
# 3490  201611    AZ  93084          7.6
# 3491  201611    AZ  93026          8.1
# 3492  201611    AZ   3196          5.9
# 3493  201612    AZ   3184          4.4
# 3494  201612    AZ  23160          6.5
# 3495  201612    AZ   3162          3.3
# 3496  201612    AZ  23183          4.9
# 3497  201612    AZ  23184          5.6
# 3498  201612    AZ   3103          7.4
# 3499  201612    AZ  93167          8.3
# 3500  201612    AZ  53146          9.1
# 3501  201612    AZ   3029          4.8
# 3502  201612    AZ  23194          6.6
# 3503  201612    AZ   3145          7.4
# 3504  201612    AZ   3195          6.8
# 3505  201612    AZ  93027          6.5
# 3506  201612    AZ   3192          2.4
# 3507  201612    AZ  93084          6.6
# 3508  201612    AZ  93026          6.6
# 3509  201612    AZ   3196          5.2
#
# [3510 rows x 4 columns]

# %%
AZ.YYMM = AZ.YYMM.astype(str)#convert items in AZ.YYMM from int to str

# %%
AZ_1996 = AZ[AZ['YYMM'].str.contains("1996")]#call all the data in 1996 for AZ
AZ_1996['Avgwindspeed'] = AZ_1996['Avgwindspeed'].astype(float)#convert items in AZ.wind from str to float
avg_AZ_1996 = sum(list(AZ_1996['Avgwindspeed']))/len(list(AZ_1996['Avgwindspeed']))
avg_AZ_1996
AZ_1996
# Out:
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       YYMM State   WBAN  Avgwindspeed
# 0   199607    AZ  93167          10.7
# 1   199607    AZ   3103           5.2
# 2   199607    AZ   3145           9.8
# 3   199607    AZ  23194           8.1
# 4   199607    AZ  23160           7.6
# 5   199607    AZ  23183           6.7
# 6   199608    AZ  23194           8.1
# 7   199608    AZ  93167          10.4
# 8   199608    AZ  23183           6.8
# 9   199608    AZ   3195           5.4
# 10  199608    AZ   3145           9.4
# 11  199608    AZ   3103           5.3
# 12  199608    AZ  23160           8.1
# 13  199609    AZ  93167           9.6
# 14  199609    AZ  23194           7.4
# 15  199609    AZ  23160           6.3
# 16  199609    AZ  23183           5.9
# 17  199609    AZ   3195           5.8
# 18  199609    AZ   3103           5.3
# 19  199609    AZ   3145           8.0
# 20  199610    AZ  93167          10.1
# 21  199610    AZ  23194           7.9
# 22  199610    AZ  23160           7.4
# 23  199610    AZ  23183           5.4
# 24  199610    AZ   3195           6.7
# 25  199610    AZ   3103           6.3
# 26  199611    AZ  23183           4.5
# 27  199611    AZ  23194           6.7
# 28  199611    AZ  93167           8.9
# 29  199611    AZ   3195           6.3
# 30  199611    AZ   3145           7.6
# 31  199611    AZ  23160           7.0
# 32  199612    AZ  93167           8.6
# 33  199612    AZ   3195           7.0
# 34  199612    AZ   3103           7.5
# 35  199612    AZ  23183           3.5
# 36  199612    AZ  23194           7.9

# %%
yearlist = ['1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006',
                 '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']
yearlist
# Out:
# ['1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
for i in yearlist:
    AZ_96to16_list = []
    AZ_96to16 = AZ[AZ['YYMM'].str.contains("i")]
    AZ_96to16['Avgwindspeed'] = AZ_96to16['Avgwindspeed'].astype(float)
    avg_AZ_96to16 = sum(list(AZ_96to16['Avgwindspeed']))/len(list(AZ_96to16['Avgwindspeed']))
    AZ_96to16_list.append(avg_AZ_96to16)
Print (AZ_96to16)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-77-788c263de4ca> in <module>()
#       3     AZ_96to16 = AZ[AZ['YYMM'].str.contains("i")]
#       4     AZ_96to16['Avgwindspeed'] = AZ_96to16['Avgwindspeed'].astype(float)
# ----> 5     avg_AZ_96to16 = sum(list(AZ_96to16['Avgwindspeed']))/len(list(AZ_96to16['Avgwindspeed']))
#       6     AZ_96to16_list.append(avg_AZ_96to16)
#       7 Print (AZ_96to16)
#
# ZeroDivisionError: division by zero

# %%
df = AZ[AZ['YYMM'].str.contains("1997")]
df
# Out:
#        YYMM State   WBAN Avgwindspeed
# 37   199701    AZ  93167          9.5
# 38   199701    AZ  23183          5.0
# 39   199701    AZ  23194          7.1
# 40   199701    AZ   3103          7.5
# 41   199701    AZ   3195          7.3
# 42   199702    AZ  23194          7.8
# 43   199702    AZ  23183          5.2
# 44   199702    AZ   3103          6.4
# 45   199702    AZ   3195          6.1
# 46   199702    AZ   3145          8.5
# 47   199702    AZ  93167          9.4
# 48   199702    AZ  23160          7.5
# 49   199703    AZ  93167          9.2
# 50   199703    AZ  23194          8.1
# 51   199703    AZ   3103          6.4
# 52   199703    AZ  23160          7.1
# 53   199703    AZ   3195          6.6
# 54   199703    AZ   3145          6.9
# 55   199704    AZ  93167         10.6
# 56   199704    AZ  23194         10.4
# 57   199704    AZ  23183          7.0
# 58   199704    AZ   3103          7.6
# 59   199704    AZ  23160          8.4
# 60   199704    AZ   3195          6.2
# 61   199705    AZ  93167         10.6
# 62   199705    AZ  23194          8.9
# 63   199705    AZ  23183          6.6
# 64   199705    AZ   3103          5.8
# 65   199705    AZ  23160          8.1
# 66   199705    AZ   3195          5.8
# ..      ...   ...    ...          ...
# 83   199708    AZ   3162          4.9
# 84   199708    AZ   3195          4.9
# 85   199708    AZ  93167         10.7
# 86   199708    AZ  23194          7.6
# 87   199708    AZ  23160          7.3
# 88   199708    AZ  23183          6.3
# 89   199709    AZ  23194          7.4
# 90   199709    AZ  93167          8.2
# 91   199709    AZ   3162          4.3
# 92   199709    AZ  23183          5.6
# 93   199709    AZ   3103          4.9
# 94   199710    AZ   3195          6.0
# 95   199710    AZ   3103          6.5
# 96   199710    AZ   3162          5.0
# 97   199710    AZ  93167          8.4
# 98   199710    AZ  23160          8.2
# 99   199711    AZ  93167          7.2
# 100  199711    AZ  23194          6.4
# 101  199711    AZ   3195          4.5
# 102  199711    AZ   3162          3.4
# 103  199711    AZ  23160          6.3
# 104  199711    AZ  23183          4.0
# 105  199711    AZ   3103          4.8
# 106  199712    AZ  93167          8.0
# 107  199712    AZ   3162          3.6
# 108  199712    AZ   3103          6.8
# 109  199712    AZ   3195          6.3
# 110  199712    AZ  23183          4.4
# 111  199712    AZ  23160          6.5
# 112  199712    AZ  23194          6.7
#
# [76 rows x 4 columns]
