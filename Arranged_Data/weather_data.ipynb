# %%
import pandas as pd
import numpy as np
import math
import os
import glob

# %%
#station data
weather_station = pd.read_csv("../Original_Data/Final_weather_data/Station_list/station_list.txt",delimiter='|')
weather_table = weather_station[['WBAN','State','Latitude','Longitude']]

# %%
#try out dataset from 199607
#building block for dataframe processing
dailyavg9607 = pd.read_csv("../Original_Data/Final_weather_data/200706dailyavg.txt",delimiter=',')
readindata = dailyavg9607.rename(columns = {'Wban Number':'WBAN'}).iloc[:,[0,6,26,-3]]
WBAN_copy = readindata['WBAN']
weather_date = pd.DataFrame(dailyavg9607.iloc[:,1]/float(100))
temp_list = []
for i in weather_date.iloc[:,0]:
    temp_list.append(math.floor(i))
    
afprocessedwd = pd.DataFrame(temp_list)
result_data = pd.concat([readindata, afprocessedwd], axis=1)
result_data.columns = ['WBAN','AvgTemp','TotalMonthlyPrecip','Avgwindspeed','YYMM']
result_data = result_data[['YYMM','WBAN','AvgTemp','TotalMonthlyPrecip','Avgwindspeed']]
final_weather_table = pd.merge(left=weather_table,right=result_data, how='left', left_on='WBAN', right_on='WBAN')

# %%
#adding iteration over all the files in the folder
path =r'../Original_Data/Final_weather_data'
allFiles = glob.glob(path + "/*.txt")
weather_frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    read_in = pd.read_csv(file_,index_col=None, header=0)
    readindata = read_in.rename(columns = {'Wban Number':'WBAN'}).iloc[:,[0,6,26,-3]]
    weather_date = pd.DataFrame(read_in.iloc[:,1]/float(100))
    temp_list = []
    for i in weather_date.iloc[:,0]:
        temp_list.append(math.floor(i))
    
    afprocessedwd = pd.DataFrame(temp_list)
    result_data = pd.concat([readindata, afprocessedwd], axis=1)
    result_data.columns = ['WBAN','AvgTemp','TotalMonthlyPrecip','Avgwindspeed','YYMM']
    result_data = result_data[['YYMM','WBAN','AvgTemp','TotalMonthlyPrecip','Avgwindspeed']]
    final_weather_table = pd.merge(left=result_data,right=weather_table, how='left', left_on='WBAN', right_on='WBAN')
    final_weather_table = final_weather_table[['YYMM','State','WBAN','Latitude','Longitude','AvgTemp','TotalMonthlyPrecip','Avgwindspeed']]
    list_.append(final_weather_table)
weather_frame = pd.concat(list_)
weather_frame.tail(20)
# Out:
#         YYMM State   WBAN  Latitude  Longitude AvgTemp TotalMonthlyPrecip  \
# 1761  200706    NE  94975    42.579    -99.984
# 1762  200706    MN  94976    44.450    -95.817
# 1763  200706    MN  94977    48.266    -92.483
# 1764  200706    NE  94978    41.764    -96.178    72.0               1.02
# 1765  200706    IA  94979    41.831    -90.318
# 1766  200706    IA  94982    41.614    -90.591    65.7               0.01
# 1767  200706    WI  94985    44.637    -90.189    66.3               1.82
# 1768  200706    MI  94986    45.126    -87.634
# 1769  200706    IA  94988    42.113    -92.918    70.2               2.95
# 1770  200706    IA  94989    41.992    -93.622    71.4               2.64
# 1771  200706    SD  94990    43.390    -99.842    70.4               2.99
# 1772  200706    IA  94991    40.633    -93.902    70.7               2.80
# 1773  200706    MN  94992    47.747    -90.344    52.6               5.22
# 1774  200706    SD  94993    45.669    -96.991    69.0               4.91
# 1775  200706    WI  94994    43.156    -90.678    68.9               4.40
# 1776  200706    MN  94997    46.447    -95.201
# 1777  200706    IA  94998    41.701    -94.917
# 1778  200706    MN  94999    46.548    -93.668
# 1779  200706    AK  96401    62.830   -149.913
# 1780  200706    AK  96402    61.731   -148.928
#
#      Avgwindspeed
# 1761
# 1762
# 1763
# 1764          9.9
# 1765
# 1766          8.0
# 1767          7.3
# 1768
# 1769          9.1
# 1770          8.4
# 1771         12.2
# 1772          7.6
# 1773          4.6
# 1774         10.6
# 1775          3.8
# 1776
# 1777
# 1778
# 1779
# 1780

# %%
path =r'../Original_Data/Final_weather_data/More'
allFiles07to16 = glob.glob(path + "/*.txt")
weather_frame07to16 = pd.DataFrame()
list07to16_ = []
for file_ in allFiles07to16:
    read_in = pd.read_csv(file_, index_col=None, header=0, error_bad_lines=False)
    result_data = read_in.rename(columns = {'Wban Number':'WBAN'}).iloc[:,[0,1,6,26,-3]]
    final_weather_table = pd.merge(left=weather_table,right=result_data, how='left', left_on='WBAN', right_on='WBAN')
    final_weather_table.columns = ['WBAN','State','Latitude','Longitude','YYMM','AvgTemp','TotalMonthlyPrecip','Avgwindspeed']
    final_weather_table = final_weather_table[['YYMM','State','WBAN','Latitude','Longitude','AvgTemp','TotalMonthlyPrecip','Avgwindspeed']]
    list07to16_.append(final_weather_table)
weather_frame07to16 = pd.concat(list07to16_)
weather_frame07to16.head(20)
# Out:
#         YYMM State  WBAN  Latitude  Longitude AvgTemp TotalMonthlyPrecip  \
# 0        NaN    CO  3011    37.954   -107.901     NaN                NaN
# 1        NaN    NM  3012    36.458   -105.667     NaN                NaN
# 2   200707.0    CO  3013    38.070   -102.688       M               0.97
# 3        NaN    NM  3014    35.789   -107.248     NaN                NaN
# 4   200707.0    CO  3016    39.526   -107.726       M               0.26
# 5   200707.0    CO  3017    39.833   -104.658       M               0.43
# 6   200707.0    TX  3024    35.700   -101.394       M               1.85
# 7   200707.0    CO  3026    39.245   -102.284       M               2.55
# 8   200707.0    NM  3027    35.003   -105.663       M               2.05
# 9   200707.0    CO  3028    37.283   -102.614       M               0.69
# 10  200707.0    AZ  3029    35.658   -109.061       M               2.23
# 11  200707.0    OK  3030    36.682   -101.505       M               1.20
# 12  200707.0    TX  3031    31.921   -102.387       M               1.72
# 13  200707.0    TX  3032    30.048   -102.213       M               1.99
# 14       NaN    NM  3033    34.985   -106.000     NaN                NaN
# 15       NaN    NM  3034    35.145   -106.784     NaN                NaN
# 16       NaN    NM  3035    32.853   -104.467     NaN                NaN
# 17       NaN    UT  3036    37.583   -109.583     NaN                NaN
# 18       NaN    KS  3037    39.428   -101.034     NaN                NaN
# 19       NaN    CO  3038    39.467   -106.150     NaN                NaN
#
#    Avgwindspeed
# 0           NaN
# 1           NaN
# 2           8.8
# 3           NaN
# 4           5.6
# 5           8.6
# 6           8.4
# 7          11.0
# 8           8.5
# 9          10.4
# 10          4.7
# 11          9.2
# 12          8.1
# 13          8.4
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN

# %%
df = [weather_frame, weather_frame07to16]
output_weather_data = pd.concat(df)
output_weather_data
# Out:
#           YYMM State   WBAN  Latitude  Longitude AvgTemp TotalMonthlyPrecip  \
# 0     199607.0    CO   3013    38.070   -102.688    74.8               1.58
# 1     199607.0    CO   3017    39.833   -104.658    73.4               1.01
# 2     199607.0    AZ   3103    35.140   -111.672    68.4               1.79
# 3     199607.0    AZ   3145    32.650   -114.617    96.4               0.12
# 4     199607.0    NV   3160    36.621   -116.028    88.4                T
# 5     199607.0    AZ   3195    35.946   -112.155    68.5               1.09
# 6     199607.0    NC   3812    35.432    -82.538    72.0               4.83
# 7     199607.0    GA   3813    32.688    -83.654    81.3               2.83
# 8     199607.0    KY   3816    37.056    -88.774    75.9               6.11
# 9     199607.0    GA   3820    33.370    -81.965    80.5               6.39
# 10    199607.0    GA   3822    32.119    -81.202    82.4               2.30
# 11    199607.0    FL   3853    30.400    -81.417    82.8               3.04
# 12    199607.0    FL   3855    30.350    -87.317    81.7               1.27
# 13    199607.0    AL   3856    34.644    -86.786    78.2               4.70
# 14    199607.0    MS   3866    32.550    -88.567    81.1               2.07
# 15    199607.0    SC   3870    34.899    -82.219    78.5               4.43
# 16    199607.0    WV   3872    37.795    -81.125    68.0               7.59
# 17    199607.0    KY   3889    37.591    -83.314    72.7               4.52
# 18    199607.0    KS   3919    38.813    -97.661    79.9               1.20
# 19    199607.0    TX   3927    32.896    -97.041    86.2               0.28
# 20    199607.0    KS   3928    37.647    -97.429    79.1               3.97
# 21    199607.0    KS   3936    39.135    -96.678    76.5               4.38
# 22    199607.0    LA   3937    30.125    -93.228    83.1               5.49
# 23    199607.0    MS   3940    32.320    -90.078    81.3               6.99
# 24    199607.0    MO   3945    38.817    -92.218    74.6               3.32
# 25    199607.0    MO   3947    39.299    -94.718    75.2               4.84
# 26    199607.0    KS   3967    38.850    -94.739    75.3               0.00
# 27    199607.0    KS   3974    37.750    -97.219    78.5                M
# 28    199607.0    TX   3991    33.206    -97.199    86.4               0.75
# 29    199607.0    MO   3994    38.704    -93.183    74.4               2.07
# ...        ...   ...    ...       ...        ...     ...                ...
# 2249  201612.0    MN  94964    47.822    -91.818       M                  M
# 2250  201612.0    MN  94966    46.289    -96.151       M                  M
# 2251  201612.0    MN  94967    46.901    -95.068       M                  M
# 2252  201612.0    MN  94968    43.681    -93.367       M                  M
# 2253  201612.0    MN  94969    44.325    -93.301       M                  M
# 2254  201612.0    IA  94971    43.408    -94.746       M                  M
# 2255  201612.0    WI  94973    46.026    -91.444       M                  M
# 2256  201612.0    MN  94974    45.145    -93.201       M                  M
# 2257  201612.0    NE  94975    42.579    -99.984       M                  M
# 2258  201612.0    MN  94976    44.450    -95.817       M                  M
# 2259  201612.0    MN  94977    48.266    -92.483       M                  M
# 2260  201612.0    NE  94978    41.764    -96.178       M                  M
# 2261  201612.0    IA  94979    41.831    -90.318       M                  M
# 2262  201612.0    IA  94982    41.614    -90.591       M                  M
# 2263  201612.0    WI  94985    44.637    -90.189       M                  M
# 2264       NaN    MI  94986    45.126    -87.634     NaN                NaN
# 2265  201612.0    IA  94988    42.113    -92.918    23.4               0.93
# 2266  201612.0    IA  94989    41.992    -93.622    24.7               1.33
# 2267  201612.0    SD  94990    43.390    -99.842       M                  M
# 2268  201612.0    IA  94991    40.633    -93.902    26.5               1.47
# 2269  201612.0    MN  94992    47.747    -90.344       M                  M
# 2270  201612.0    SD  94993    45.669    -96.991       M                  M
# 2271  201612.0    WI  94994    43.156    -90.678       M                  M
# 2272  201612.0    NE  94995    40.848    -96.565    26.2               1.32
# 2273  201612.0    NE  94996    40.695    -96.854    26.5               1.38
# 2274  201612.0    MN  94997    46.447    -95.201       M                  M
# 2275  201612.0    IA  94998    41.701    -94.917       M                  M
# 2276  201612.0    MN  94999    46.548    -93.668       M                  M
# 2277  201612.0    AK  96401    62.830   -149.913       M                  M
# 2278       NaN    AK  96402    61.731   -148.928     NaN                NaN
#
#      Avgwindspeed
# 0             8.5
# 1             9.7
# 2             5.2
# 3             9.8
# 4             9.7
# 5
# 6             4.4
# 7             5.9
# 8             4.9
# 9             6.1
# 10            5.8
# 11
# 12            6.7
# 13            5.6
# 14            3.4
# 15            5.4
# 16            5.5
# 17            4.2
# 18            9.6
# 19            9.3
# 20            9.4
# 21            6.6
# 22            4.6
# 23            4.0
# 24            8.0
# 25            8.1
# 26            7.3
# 27
# 28            8.5
# 29            7.2
# ...           ...
# 2249            M
# 2250            M
# 2251         10.9
# 2252            M
# 2253            M
# 2254         15.2
# 2255          7.3
# 2256            M
# 2257            M
# 2258            M
# 2259            M
# 2260         11.6
# 2261            M
# 2262         12.6
# 2263         11.3
# 2264          NaN
# 2265         12.6
# 2266         11.4
# 2267         13.7
# 2268         10.6
# 2269          8.9
# 2270         15.2
# 2271          6.5
# 2272            M
# 2273            M
# 2274            M
# 2275            M
# 2276            M
# 2277            M
# 2278          NaN
#
# [393569 rows x 8 columns]

# %%
output_weather_data.to_csv('final_weather_table')
