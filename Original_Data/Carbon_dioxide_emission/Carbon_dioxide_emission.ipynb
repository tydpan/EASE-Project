# %%
import pandas as pd
import numpy as np
import xlrd
import csv
import math
import os
import glob

# %%
excel_files = glob.glob('*xlsx*')
for excel in excel_files:
    out = excel.split('.')[0]+'.csv'
    df = pd.read_excel(excel, 'Sheet1')
    df.to_csv(out)

# %%
df = pd.read_csv('delaware.csv',header=None)
df
# Out:
#       0                                                  1   \
# 0    NaN  Delaware Carbon Dioxide Emissions from Fossil ...
# 1    0.0                         million metric tons of CO2
# 2    1.0                                                NaN
# 3    2.0                                                NaN
# 4    3.0                                 Residential Sector
# 5    4.0                                                NaN
# 6    5.0                                                NaN
# 7    6.0                                                NaN
# 8    7.0                                                NaN
# 9    8.0                                                NaN
# 10   9.0                                  Commercial Sector
# 11  10.0                                                NaN
# 12  11.0                                                NaN
# 13  12.0                                                NaN
# 14  13.0                                                NaN
# ...

# %%
df = pd.read_csv('delaware.csv',header=None)
data = df.loc[29:32]
dataT = data.T
dataT
#states = ['DE']
#newstates = pd.DataFrame({'states': ['DE']})
year = pd.DataFrame(df.loc[3, 3:])
coal = pd.DataFrame(dataT.loc[3:,29])
petro = pd.DataFrame(dataT.loc[3:,30])
ng = pd.DataFrame(dataT.loc[3:,31])
total = pd.DataFrame(dataT.loc[3:,32])
source_list = [year, coal, petro, ng, total]
result = pd.concat(source_list, axis=1)
result.columns = ['year','coal','petro','ng','total']
result.reset_index(inplace=True, drop=True)
result
#states = ['DE']
#result.append(states)
#result
#year = df.loc[2]
#new_df = pd.concat((newdata, year), axis=1)
#new_df.reset_index(inplace=True)
#new_df
#new_df.shape
#new_df.columns = new_df.iloc[2]
#new_df
#for i in year:
#    year += list(np.full(len(statelist),i,dtype = int))
#year
# Out:
#       year coal petro   ng total
# 0   1980.0  2.2   3.3  0.4   5.8
# 1   1981.0  4.3   2.8  0.3   7.4
# 2   1982.0  4.1   2.0  0.3   6.3
# 3   1983.0  6.5   2.0  0.3   8.8
# 4   1984.0  6.4   1.8  0.4   8.6
# 5   1985.0  6.2   1.6  0.4   8.2
# 6   1986.0  5.7   2.1  0.1   8.0
# 7   1987.0  6.0   1.5  0.4   8.0
# 8   1988.0  5.9   2.4  0.2   8.4
# 9   1989.0  5.2   2.1  0.4   7.8
# 10  1990.0  5.0   1.9  0.5   7.5
# 11  1991.0  4.8   2.2  0.7   7.8
# 12  1992.0  4.0   2.4  0.4   6.8
# 13  1993.0  5.5   1.7  0.4   7.6
# 14  1994.0  4.9   1.3  0.9   7.1
# 15  1995.0  4.5   0.7  1.5   6.7
# 16  1996.0  4.4   1.0  1.3   6.6
# 17  1997.0  4.2   0.7  0.9   5.7
# 18  1998.0  3.9   1.0  0.6   5.5
# 19  1999.0  3.0   1.0  1.0   5.1
# 20  2000.0  4.3   0.5  0.5   5.3
# 21  2001.0  3.2   1.2  0.8   5.2
# 22  2002.0  3.6   0.6  0.9   5.1
# 23  2003.0  4.2   1.0  0.6   5.9
# 24  2004.0  4.8   0.5  0.7   6.0
# 25  2005.0  5.1   0.6  0.7   6.4
# 26  2006.0  5.1   0.1  0.5   5.7
# ...

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}
# Out:
# {'NE': 'Nebraska', 'SC': 'South Carolina', 'DE': 'Delaware', 'MT': 'Montana', 'TN': 'Tennessee', 'AK': 'Alaska', 'TX': 'Texas', 'CA': 'California', 'NV': 'Nevada', 'CO': 'Colorado', 'DC': 'District of Columbia', 'ND': 'North Dakota', 'ME': 'Maine', 'IL': 'Illinois', 'VA': 'Virginia', 'OK': 'Oklahoma', 'WY': 'Wyoming', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'AZ': 'Arizona', 'MO': 'Missouri', 'HI': 'Hawaii', 'WA': 'Washington', 'WV': 'West Virginia', 'NC': 'North Carolina', 'WI': 'Wisconsin', 'NH': 'New Hampshire', 'IA': 'Iowa', 'SD': 'South Dakota', 'NJ': 'New Jersey', 'ID': 'Idaho', 'OH': 'Ohio', 'MI': 'Michigan', 'KY': 'Kentucky', 'VT': 'Vermont', 'UT': 'Utah', 'AL': 'Alabama', 'KS': 'Kansas', 'MD': 'Maryland', 'FL': 'Florida', 'MA': 'Massachusetts', 'AR': 'Arkansas', 'IN': 'Indiana', 'PA': 'Pennsylvania', 'OR': 'Oregon', 'NY': 'New York', 'CT': 'Connecticut', 'MN': 'Minnesota', 'LA': 'Louisiana', 'GA': 'Georgia', 'MS': 'Mississippi'}
# ...

# %%
abc = sorted(list(states.values()))
abc[24] = 'Missouri'
abc[25] = 'Mississippi'

# %%
state =[]
for j in abc:
    for i in range(35):
        state.append(reverstates[j])
len(state)
# Out:
# 1785

# %%
abcdef = sorted(list(states.keys()))
reverstates = {}
for i in abcdef:
    reverstates[states[i]] = i
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
# ...

# %%
path =r'C:\Users\yongquan\EASE-Project\Original_Data\Carbon_dioxide_emission'
alldatas = glob.glob(path + "/*.csv")
carbon_emission_80to14 = pd.DataFrame()
list80to14_ = []
for data_ in alldatas:  
    read_in = pd.read_csv(data_, index_col=None, header=None, error_bad_lines=False)
    result_data = read_in.loc[29:32]
    dataT = result_data.T
    year = pd.DataFrame(df.loc[3, 3:])
    coal = pd.DataFrame(dataT.loc[3:,29])
    petro = pd.DataFrame(dataT.loc[3:,30])
    ng = pd.DataFrame(dataT.loc[3:,31])
    total = pd.DataFrame(dataT.loc[3:,32])
    source_list = [year, coal, petro, ng, total]
    new_result = pd.concat(source_list, axis=1)
    new_result.columns = ['Year','Coal','Petroleum','NatrualGas','Total']
#    carbon_emission_table = 
#    year = read_in.loc[2]
#    new_table = pd.concat((carbon_emission_table, year), axis=1)
#    new_table.columns = ['Coal', 'Petroleum Products', 'Natural Gas', 'Total', 'Year']
    list80to14_.append(new_result)
carbon_emission_80to14 = pd.concat(list80to14_)
carbon_emission_80to14.reset_index(inplace=True, drop=True)
carbon_emission_80to14['State'] = state
carbon_emission_80to14 = carbon_emission_80to14.sort(['Year','State'])
carbon_emission_80to14.Year = carbon_emission_80to14.Year.astype(float).astype(int)
carbon_emission_80to14.reset_index(inplace=True, drop=True)
carbon_emission_80to14
# Out:
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       Year   Coal Petroleum NatrualGas  Total State
# 0     1980    0.4       0.4        1.5    2.3    AK
# 1     1980   43.9       0.1        0.1   44.1    AL
# 2     1980    2.8       1.6        3.2    7.6    AR
# 3     1980   21.7       0.8        2.8   25.3    AZ
# 4     1980    0.0      32.1       29.0   61.1    CA
# 5     1980   19.0       0.2        1.6   20.8    CO
# 6     1980    0.0      10.7        0.0   10.7    CT
# 7     1980    0.0       0.8        0.0    0.8    DC
# 8     1980    2.2       3.3        0.4    5.8    DE
# 9     1980   19.5      36.0        8.9   64.5    FL
# 10    1980   47.3       0.5        0.2   48.0    GA
# 11    1980    0.0       5.5        0.0    5.5    HI
# 12    1980   18.8       0.1        0.4   19.2    IA
# 13    1980    0.0       0.0        0.0    0.0    ID
# ...

# %%
# check the order of csv file read in for loop
carbon_emission_80to14.loc[245:]
# Out:
#         Year  Coal Petroleum NatrualGas Total
# 245   1980.0   2.2       3.3        0.4   5.8
# 246   1981.0   4.3       2.8        0.3   7.4
# 247   1982.0   4.1       2.0        0.3   6.3
# 248   1983.0   6.5       2.0        0.3   8.8
# 249   1984.0   6.4       1.8        0.4   8.6
# 250   1985.0   6.2       1.6        0.4   8.2
# 251   1986.0   5.7       2.1        0.1   8.0
# 252   1987.0   6.0       1.5        0.4   8.0
# 253   1988.0   5.9       2.4        0.2   8.4
# 254   1989.0   5.2       2.1        0.4   7.8
# 255   1990.0   5.0       1.9        0.5   7.5
# 256   1991.0   4.8       2.2        0.7   7.8
# 257   1992.0   4.0       2.4        0.4   6.8
# 258   1993.0   5.5       1.7        0.4   7.6
# 259   1994.0   4.9       1.3        0.9   7.1
# 260   1995.0   4.5       0.7        1.5   6.7
# 261   1996.0   4.4       1.0        1.3   6.6
# 262   1997.0   4.2       0.7        0.9   5.7
# 263   1998.0   3.9       1.0        0.6   5.5
# ...

# %%
int(float(str('1980.0')))
# Out:
# 1980
