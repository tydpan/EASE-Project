# %%
import pandas as pd
import numpy as np
import xlrd
import csv
import math
import os
import glob

# %%
data_xls = pd.read_excel('alabama.xlsx', 'Sheet1', index_col=None)
data_xls.to_csv('alabama.csv', encoding='utf-8')
data_xls
# Out:
#    Alabama Carbon Dioxide Emissions from Fossil Fuel Consumption (1980-2014)  \
# 0                          million metric tons of CO2
# 1                                                 NaN
# 2                                                 NaN
# 3                                  Residential Sector
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                   Commercial Sector
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                  Industrial Sector
# ...

# %%
df = data_xls.loc[28:31]
df.T
# Out:
#                                                       28                  29  \
# Alabama Carbon Dioxide Emissions from Fossil Fu...   NaN                 NaN
# Unnamed: 1                                          Coal  Petroleum Products
# Unnamed: 2                                          43.9                 0.1
# Unnamed: 3                                          43.9                   0
# Unnamed: 4                                          35.2                   0
# Unnamed: 5                                          38.7                 0.1
# Unnamed: 6                                          40.2                   0
# Unnamed: 7                                          48.8                   0
# Unnamed: 8                                          49.1                   0
# Unnamed: 9                                          47.7                   0
# Unnamed: 10                                         45.8                 0.1
# ...

# %%
year = list(data_xls.loc[2])
year
# Out:
# [nan,
#  nan,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0]

# %%
excel_files = glob.glob('*xlsx*')
for excel in excel_files:
    out = excel.split('.')[0]+'.csv'
    df = pd.read_excel(excel, 'Sheet1')
    df.to_csv(out)

# %%
df = pd.read_csv('alaska.csv')
data = df.loc[28:31]
newdata = data.T
year = df.loc[2]
new_df = pd.concat((newdata, year), axis=1)
new_df
new_df.reset_index(inplace=True)
new_df
#new_df.shape
#new_df.columns = new_df.iloc[2]
#new_df
# Out:
#                                                 index    28  \
# 0                                          Unnamed: 0    28
# 1   Alaska Carbon Dioxide Emissions from Fossil Fu...   NaN
# 2                                          Unnamed: 1  Coal
# 3                                          Unnamed: 2   0.4
# 4                                          Unnamed: 3   0.5
# 5                                          Unnamed: 4   0.5
# 6                                          Unnamed: 5   0.5
# 7                                          Unnamed: 6   0.5
# 8                                          Unnamed: 7   0.4
# 9                                          Unnamed: 8   0.4
# 10                                         Unnamed: 9   0.4
# 11                                        Unnamed: 10   0.4
# 12                                        Unnamed: 11   0.4
# 13                                        Unnamed: 12   0.4
# 14                                        Unnamed: 13   0.4
# ...

# %%
path =r'C:\Users\yongquan\EASE-Project\Original_Data\Carbon_dioxide_emission'
alldatas = glob.glob(path + "/*.csv")
carbon_emission_80to14 = pd.DataFrame()
list80to14_ = []
for data_ in alldatas:
    read_in = pd.read_csv(data_, index_col=None, header=0, error_bad_lines=False)
    result_data = read_in.loc[28:31]
    carbon_emission_table = result_data.T
    year = read_in.loc[2]
    new_table = pd.concat((carbon_emission_table, year), axis=1)
    new_table.columns = ['Coal', 'Petroleum Products', 'Natural Gas', 'Total', 'Year']
    list80to14_.append(new_table)
carbon_emission_80to14 = pd.concat(list80to14_)
carbon_emission_80to14
# Out:
#                                                     Coal  Petroleum Products  \
# Unnamed: 0                                            28                  29
# Alabama Carbon Dioxide Emissions from Fossil Fu...   NaN                 NaN
# Unnamed: 1                                          Coal  Petroleum Products
# Unnamed: 2                                          43.9                 0.1
# Unnamed: 3                                          43.9                   0
# Unnamed: 4                                          35.2                   0
# Unnamed: 5                                          38.7                 0.1
# Unnamed: 6                                          40.2                   0
# Unnamed: 7                                          48.8                   0
# Unnamed: 8                                          49.1                   0
# Unnamed: 9                                          47.7                   0
# ...

# %%
#newcarbon = carbon_emission_80to14.reset_index()
#newcarbon
carbon_emission_80to14
# Out:
# pandas.core.frame.DataFrame

# %%
statelist = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
print (statelist)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
carbon_emission_80to14['Coal']
#arranged_data = data.drop(['Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9'],axis = 1)
# Out:
# Unnamed: 0                                                                     28
# Alabama Carbon Dioxide Emissions from Fossil Fuel Consumption (1980-2014)     NaN
# Unnamed: 1                                                                   Coal
# Unnamed: 2                                                                   43.9
# Unnamed: 3                                                                   43.9
# Unnamed: 4                                                                   35.2
# Unnamed: 5                                                                   38.7
# Unnamed: 6                                                                   40.2
# Unnamed: 7                                                                   48.8
# Unnamed: 8                                                                   49.1
# Unnamed: 9                                                                   47.7
# ...
