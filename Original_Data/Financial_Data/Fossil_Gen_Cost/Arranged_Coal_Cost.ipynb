# %%
import pandas as pd
import numpy as np
import os

# %%
#load the data and get the transpose
data_coal = pd.read_csv("coal_cost.csv",error_bad_lines=False).T

# %%
data_coal.columns = data_coal.iloc[0]# rename the column heads
data_coal.reset_index(drop=True,inplace=True)# reset the row index

# %%
#delete all the useless columns
data_coal.dropna(axis=1,inplace=True)# delete nan columns in inner dataframe

# %%
#del data_coal['electric power']

# %%
data_coal
# Out:
# Average cost of fossil fuels for electricity generation (per Btu) for coal  description  \
# 0                                                                           description
# 1                                                                                 units
# 2                                                                            source key
# 3                                                                                Jan-08
# 4                                                                                Feb-08
# 5                                                                                Mar-08
# 6                                                                                Apr-08
# 7                                                                                May-08
# 8                                                                                Jun-08
# 9                                                                                Jul-08
# ...

# %% [markdown]
# coal = pd.read_csv("coal_cost.csv",error_bad_lines=False)

# %% [markdown]
# coal.drop([0,1,2],inplace=True)#drop nan rows
# coal.reset_index(drop=True,inplace=True)# reset the row index

# %% [markdown]
# coal
